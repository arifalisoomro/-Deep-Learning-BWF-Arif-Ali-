# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style

# %%
df0 = pd.read_csv('states0.csv')
df1 = pd.read_csv('states1.csv')
df2 = pd.read_csv('states2.csv')
df3 = pd.read_csv('states3.csv')
df4 = pd.read_csv('states4.csv')
df5 = pd.read_csv('states5.csv')
df6 = pd.read_csv('states6.csv')
df7 = pd.read_csv('states7.csv')
df8 = pd.read_csv('states8.csv')
df9 = pd.read_csv('states9.csv')

# %%
df0
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
# 5           5    Colorado   5278906   20.78438003220608%   69.89557165861504%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
# ...

# %%
combined_df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9] , ignore_index=True)

# %%
combined_df.to_csv('combined_df' , index = False)

# %%
df = pd.read_csv('combined_df')
df
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0              Colorado   5278906   20.78438003220608%
# 1            1           Connecticut   3593222  15.604830917874388%
# 2            2              Delaware    926454    8.82476635514019%
# 3            3  District of Columbia    647484   9.165921787709499%
# 4            4               Florida  19645772    21.3385426653884%
# 5            5               Georgia  10006693   8.418242207460397%
# 6            0               Georgia  10006693   8.418242207460397%
# 7            1                Hawaii   1406299   9.186708860759486%
# 8            2                 Idaho   1616547  11.505369127516781%
# 9            3              Illinois  12873761  15.601733547351516%
# 10           4               Indiana   6568645   6.536744186046501%
# 11           5                  Iowa   3093526    5.30364520048603%
# 12           0                  Iowa   3093526    5.30364520048603%
# ...

# %%
df = df.iloc[:,1:]
df
# Out:
#                    State  TotalPop             Hispanic                White  \
# 0               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 1            Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 2               Delaware    926454    8.82476635514019%   64.63271028037383%
# 3   District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 4                Florida  19645772    21.3385426653884%   59.08374880153398%
# 5                Georgia  10006693   8.418242207460397%   54.28630556974962%
# 6                Georgia  10006693   8.418242207460397%   54.28630556974962%
# 7                 Hawaii   1406299   9.186708860759486%  25.032278481012657%
# 8                  Idaho   1616547  11.505369127516781%    83.1362416107383%
# 9               Illinois  12873761  15.601733547351516%   60.85980738362764%
# 10               Indiana   6568645   6.536744186046501%   78.43189368770771%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      54 non-null     object
#  1   TotalPop   54 non-null     int64
#  2   Hispanic   54 non-null     object
#  3   White      54 non-null     object
#  4   Black      54 non-null     object
#  5   Native     54 non-null     object
#  6   Asian      54 non-null     object
#  7   Pacific    50 non-null     object
#  8   Income     54 non-null     object
#  9   GenderPop  54 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ KB

# %%
df.isnull()
# Out:
#     State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  Income  \
# 0   False     False     False  False  False   False  False     True   False
# 1   False     False     False  False  False   False  False    False   False
# 2   False     False     False  False  False   False  False     True   False
# 3   False     False     False  False  False   False  False    False   False
# 4   False     False     False  False  False   False  False    False   False
# 5   False     False     False  False  False   False  False    False   False
# 6   False     False     False  False  False   False  False    False   False
# 7   False     False     False  False  False   False  False    False   False
# 8   False     False     False  False  False   False  False    False   False
# 9   False     False     False  False  False   False  False    False   False
# 10  False     False     False  False  False   False  False    False   False
# ...

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 1 to 53
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      42 non-null     object
#  1   TotalPop   42 non-null     int64
#  2   Hispanic   42 non-null     object
#  3   White      42 non-null     object
#  4   Black      42 non-null     object
#  5   Native     42 non-null     object
#  6   Asian      42 non-null     object
#  7   Pacific    42 non-null     object
#  8   Income     42 non-null     object
#  9   GenderPop  42 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 3.6+ KB

# %%
df = df.reset_index(drop =True)

# %%
df[['Male','Female']] = df['GenderPop'].str.split('_',expand = True)

# %%
df['Male'] = df['Male'].str.replace('M','')

# %%
df['Female'] = df['Female'].str.replace('F','')

# %%
df['Male'] = df['Male'].astype(int)

# %%
df["Female"][12] = 2900655
# Out:
# C:\Users\mosai\AppData\Local\Temp\ipykernel_7092\2094601370.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Female"][12] = 2900655

# %%
df["Female"][14] = 2900655
# Out:
# C:\Users\mosai\AppData\Local\Temp\ipykernel_7092\3515725951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Female"][14] = 2900655

# %%
df["Female"][18] = 2900655
# Out:
# C:\Users\mosai\AppData\Local\Temp\ipykernel_7092\3063036996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Female"][18] = 2900655

# %%
df['Female']
# Out:
# 0      1841615
# 1       340810
# 2     10045763
# 3      5123362
# 4       696428
# 5       806083
# 6      6556862
# 7      3333382
# 8      1558931
# 9      2233145
# 10     2364097
# 11      679019
# 12     2900655
# 13     3455936
# 14     2900655
# 15     2727005
# 16     1536358
# 17     3081445
# 18     2900655
# 19      939759
# 20     1390901
# 21      670717
# 22     4561386
# 23     1051703
# 24    10131373
# 25     5049925
# 26     5913084
# 27     1942789
# 28     1990780
# 29     6534215
# 30     1869213
# 31      543273
# 32     2455167
# 33      419713
# 34     3331859
# 35    13367298
# 36     1444150
# 37      318031
# 38     4195682
# 39     3497739
# 40      937789
# 41     2890732
# Name: Female, dtype: object

# %%
df['Female'] = df['Female'].astype(int)

# %%
df['Female'].mean()
# Out:
# 3107844.8571428573

# %%
df.head()
# Out:
#                   State  TotalPop             Hispanic                White  \
# 0           Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 1  District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 2               Florida  19645772    21.3385426653884%   59.08374880153398%
# 3               Georgia  10006693   8.418242207460397%   54.28630556974962%
# 4                Hawaii   1406299   9.186708860759486%  25.032278481012657%
#
#                  Black                Native                Asian  \
# 0   10.34806763285027%  0.12620772946859898%   4.021980676328502%
# 1   51.77653631284915%  0.20055865921787713%  3.3832402234636865%
# 2  15.165675934803444%   0.2104506232023015%  2.2831735378715257%
# 3   32.08829841594277%  0.18758303525804798%  3.0976494634644895%
# 4   2.052848101265823%   0.1449367088607596%   36.59208860759495%
#
#                  Pacific               Income           GenderPop     Male  \
# ...

# %%
df['Hispanic'] = df['Hispanic'].str.replace("%","").astype(float)

# %%
df['White'] = df['White'].str.replace("%","").astype(float)

# %%
df['Black'] = df['Black'].str.replace("%","").astype(float)

# %%
df['Native'] = df['Native'].str.replace("%","").astype(float)

# %%
df['Asian'] = df['Asian'].str.replace("%","").astype(float)

# %%
df['Pacific'] = df['Pacific'].str.replace("%","").astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      42 non-null     object
#  1   TotalPop   42 non-null     int64
#  2   Hispanic   42 non-null     float64
#  3   White      42 non-null     float64
#  4   Black      42 non-null     float64
#  5   Native     42 non-null     float64
#  6   Asian      42 non-null     float64
#  7   Pacific    42 non-null     float64
#  8   Income     42 non-null     object
#  9   GenderPop  42 non-null     object
#  10  Male       42 non-null     int32
#  11  Female     42 non-null     int32
# dtypes: float64(6), int32(2), int64(1), object(3)
# memory usage: 3.7+ KB

# %% [markdown]
# ### Graph-1
#  The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.

# %%
style.use('ggplot')
plt.figure(figsize = (9,9))
sns.scatterplot(x=df['Female'],y=df['Income'])
plt.xticks(rotation = 90)
plt.title("Avg Income in a state vs proportion of women")
plt.show()

# %%
df.head()
# Out:
#                   State  TotalPop   Hispanic      White      Black    Native  \
# 0           Connecticut   3593222  15.604831  67.677053  10.348068  0.126208
# 1  District of Columbia    647484   9.165922  33.103911  51.776536  0.200559
# 2               Florida  19645772  21.338543  59.083749  15.165676  0.210451
# 3               Georgia  10006693   8.418242  54.286306  32.088298  0.187583
# 4                Hawaii   1406299   9.186709  25.032278   2.052848  0.144937
#
#        Asian   Pacific               Income           GenderPop     Male  \
# 0   4.021981  0.018599    $76146.5605875153   1751607M_1841615F  1751607
# 1   3.383240  0.029609   $75466.36363636363     306674M_340810F   306674
# 2   2.283174  0.051510  $50690.194986743794  9600009M_10045763F  9600009
# 3   3.097649  0.046602   $50811.08205128205   4883331M_5123362F  4883331
# 4  36.592089  8.758861   $73264.42628205128     709871M_696428F   709871
#
#      Female
# 0   1841615
# 1    340810
# 2  10045763
# ...

# %%
# Converting From % to normal numbers
df["Hispanic"] = df["Hispanic"] * 100

# %%
style.use('ggplot')
plt.figure(figsize = (9,9))
sns.barplot(x = df['Hispanic'] , y= df['State'])
plt.xticks(rotation = 90)
plt.title("Histogram Between State and Hispanic")
plt.show()

# %%
# Converting From % to normal numbers
df["White"] = df["White"] * 100

# %%
style.use('ggplot')
plt.figure(figsize = (9,9))
sns.barplot(x = df['White'] , y= df['State'])
plt.xticks(rotation = 90)
plt.title("Histogram Between State and White")
plt.show()

# %%
# Converting From % to normal numbers
df["Black"] = df["Black"] * 100

# %%
style.use('ggplot')
plt.figure(figsize = (9,9))
sns.barplot(x = df['Black'] , y= df['State'])
plt.xticks(rotation = 90)
plt.title("Histogram Between State and Black")
plt.show()

# %%
# Converting From % to normal numbers
df["Native"] = df["Native"] * 100

# %%
style.use('ggplot')
plt.figure(figsize = (9,9))
sns.barplot(x = df['Native'] , y= df['State'])
plt.xticks(rotation = 90)
plt.title("Histogram Between State and Native")
plt.show()

# %%
# Converting From % to normal numbers
df["Asian"] = df["Asian"] * 100

# %%
style.use('ggplot')
plt.figure(figsize = (9,9))
sns.barplot(x = df['Asian'] , y= df['State'])
plt.xticks(rotation = 90)
plt.title("Histogram Between State and Asian")
plt.show()

# %%
# Converting From % to normal numbers
df["Pacific"] = df["Pacific"] * 100

# %%
style.use('ggplot')
plt.figure(figsize = (9,9))
sns.barplot(x = df['Pacific'] , y= df['State'])
plt.xticks(rotation = 90)
plt.title("Histogram Between State and Pacific")
plt.show()
